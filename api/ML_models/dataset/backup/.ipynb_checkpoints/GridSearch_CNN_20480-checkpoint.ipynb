# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "ann"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
from NN_model import DNNClassifier, CNNClassifier, GridSearchCNN, GridSearchDNN

# %%
processedDataX_path = "preprocessedSamples_X_samples_allGuitar_20480_Mm7_R1B.data"
processedDatay_path = "preprocessedSamples_y_samples_allGuitar_20480_Mm7_R1B.data"
processedData_path = ""

if os.path.isfile(processedDataX_path): #if already preprocessed
	processedX = np.load(processedDataX_path)
	processedy = np.load(processedDatay_path)
else:
	df = pd.read_csv('samples_allGuitar_20480_Mm7_R1B.csv')
	# df = pd.read_csv('samples_nylonGuitar_1024_Mm7_R03.csv')
	# df = pd.read_csv('../CachedData.csv')

	X_load = np.array(df.iloc[:,:-1], dtype=np.float)
	y_load = np.array(df.iloc[:,-1], dtype=np.float)
	processedX = np.zeros((len(X_load),12,80,1), dtype=np.float)
	processedy = np.zeros(len(y_load), dtype=np.float)
	for i in range(len(X_load)):
		# sample = librosa.core.stft(y=X_load[i], n_fft=2048, win_length=128, window='hamming', center=True, dtype=np.float32, pad_mode='reflect')
		sample = librosa.feature.chroma_stft(y=X_load[i], sr=44100, n_fft=20480, hop_length=258)
		sample = np.atleast_3d(sample)
		processedX[i] = sample
		processedy[i] = y_load[i]
		if i % 400 == 0:
			print(i)
	
	processedX.dump(processedDataX_path)
	processedy.dump(processedDatay_path)

from sklearn.utils import shuffle
print(processedy)
sprocessedX, sprocessedy = shuffle(processedX, processedy)
print(len(sprocessedX))
	
trainRange = int(len(sprocessedX) * 0.9)
validRange = int(len(sprocessedX) * 1)
testRange = int(len(sprocessedX) * 0.1)


X_train = np.array(sprocessedX[:trainRange], dtype=np.float)
y_train = np.array(sprocessedy[:trainRange], dtype=np.float)

X_valid = np.array(sprocessedX[trainRange:validRange], dtype=np.float)
y_valid = np.array(sprocessedy[trainRange:validRange], dtype=np.float)

X_test = np.array(sprocessedX[testRange:], dtype=np.float)
y_test = np.array(sprocessedy[testRange:], dtype=np.float)
print(y_test[1])
# Out:
#   File "<ipython-input-3-55d21af955d1>", line 23
#     if i % 400 == 0:
#                     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
import tensorflow as tf

def leaky_relu(alpha=0.01):
		def parametrized_leaky_relu(z, name=None):
			return tf.maximum(alpha * z, z, name=name)
		return parametrized_leaky_relu

params = {'n_hidden_layers': [5],
	'n_neurons' : [700],
	'optimizer_class' : [tf.train.AdagradOptimizer],
	'learning_rate' : [0.05],
	'batch_size' : [50],
	'activation' : [leaky_relu()],
	'dropout_rate' : [0.2],
	'conv1' : [{'conv1_fmaps':16, 'conv1_ksize':5, 'conv1_stride':1, 'conv1_dropout':None, 'conv1_activation':tf.nn.relu}],
	'conv2' : [{'conv2_fmaps':32, 'conv2_ksize':5, 'conv2_stride':1, 'conv2_dropout':0.2, 'conv2_activation':tf.nn.relu}],
    'architecture' : [2]
}

grid_search = GridSearchCNN(params, k_fold=5)
grid_search.fit(X_train, y_train, X_valid, y_valid)
# Out:
# Trining CNN with parameters: n_hidden_layers: 5, n_neurons: 700, optimizer_class: <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, learning_rate: 0, batch_size: 50, activation: <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF1E0BA048>, dropout_rate: 0, architecture: 2, conv1: {'conv1_fmaps': 16, 'conv1_ksize': 5, 'conv1_stride': 1, 'conv1_dropout': None, 'conv1_activation': <function relu at 0x000001AF17B97F28>}, conv2: {'conv2_fmaps': 32, 'conv2_ksize': 5, 'conv2_stride': 1, 'conv2_dropout': 0.2, 'conv2_activation': <function relu at 0x000001AF17B97F28>} .
# Training and testing fold 0
# ranges:
# 1400 1750
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 20.0000%, valid. accuracy: 26.1538%, valid. best loss: 3.042104
# Epoch 1, train accuracy: 65.0000%, valid. accuracy: 47.1795%, valid. best loss: 2.056658
# Epoch 2, train accuracy: 45.0000%, valid. accuracy: 56.4103%, valid. best loss: 1.206949
# Epoch 3, train accuracy: 70.0000%, valid. accuracy: 62.0513%, valid. best loss: 1.153115
# Epoch 4, train accuracy: 90.0000%, valid. accuracy: 71.7949%, valid. best loss: 0.934034
# Epoch 5, train accuracy: 80.0000%, valid. accuracy: 71.7949%, valid. best loss: 0.934034
# Epoch 6, train accuracy: 80.0000%, valid. accuracy: 65.6410%, valid. best loss: 0.934034
# Epoch 7, train accuracy: 85.0000%, valid. accuracy: 71.7949%, valid. best loss: 0.934034
# Epoch 8, train accuracy: 90.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.749164
# Epoch 9, train accuracy: 80.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.749164
# Epoch 10, train accuracy: 65.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.749164
# Epoch 11, train accuracy: 75.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.749164
# Epoch 12, train accuracy: 70.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.603175
# Epoch 13, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.603175
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.603175
# Epoch 15, train accuracy: 90.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.603175
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.603175
# Epoch 17, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.603175
# Epoch 18, train accuracy: 95.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.603175
# Epoch 19, train accuracy: 95.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.603175
# Epoch 20, train accuracy: 90.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.603175
# Epoch 21, train accuracy: 95.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.603175
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.603175
# Epoch 23, train accuracy: 85.0000%, valid. accuracy: 73.8462%, valid. best loss: 0.603175
# Epoch 24, train accuracy: 90.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.603175
# Epoch 25, train accuracy: 90.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.603175
# Epoch 26, train accuracy: 95.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.603175
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.603175
# Early stopping!
# Final accuracy on test set: 0.834286
# Training and testing fold 1
# ranges:
# 1050 1400
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 20.0000%, valid. accuracy: 33.3333%, valid. best loss: 2.747304
# Epoch 1, train accuracy: 55.0000%, valid. accuracy: 52.8205%, valid. best loss: 2.020759
# Epoch 2, train accuracy: 60.0000%, valid. accuracy: 52.3077%, valid. best loss: 1.500030
# Epoch 3, train accuracy: 70.0000%, valid. accuracy: 58.9744%, valid. best loss: 1.219484
# Epoch 4, train accuracy: 90.0000%, valid. accuracy: 63.5897%, valid. best loss: 1.146571
# Epoch 5, train accuracy: 80.0000%, valid. accuracy: 70.2564%, valid. best loss: 1.101550
# Epoch 6, train accuracy: 85.0000%, valid. accuracy: 72.3077%, valid. best loss: 0.747983
# Epoch 7, train accuracy: 75.0000%, valid. accuracy: 62.5641%, valid. best loss: 0.737429
# Epoch 8, train accuracy: 85.0000%, valid. accuracy: 70.7692%, valid. best loss: 0.737429
# Epoch 9, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.737429
# Epoch 10, train accuracy: 90.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.737429
# Epoch 11, train accuracy: 90.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.737429
# Epoch 12, train accuracy: 95.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.708824
# Epoch 13, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.708824
# Epoch 14, train accuracy: 90.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.708824
# Epoch 15, train accuracy: 90.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.708824
# Epoch 16, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.708824
# Epoch 17, train accuracy: 95.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.708824
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.708824
# Epoch 19, train accuracy: 95.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.625754
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 74.8718%, valid. best loss: 0.625754
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.625754
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.625754
# Epoch 23, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.625754
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.625754
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.625754
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.625754
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.625754
# Epoch 28, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.625754
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.625754
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.625754
# Epoch 31, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.625754
# Epoch 32, train accuracy: 95.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.625754
# Epoch 33, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.625754
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.625754
# Early stopping!
# Final accuracy on test set: 0.834286
# Training and testing fold 2
# ranges:
# 700 1050
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 45.0000%, valid. accuracy: 36.9231%, valid. best loss: 2.834323
# Epoch 1, train accuracy: 55.0000%, valid. accuracy: 46.1538%, valid. best loss: 1.747032
# Epoch 2, train accuracy: 70.0000%, valid. accuracy: 63.0769%, valid. best loss: 1.159356
# Epoch 3, train accuracy: 70.0000%, valid. accuracy: 68.2051%, valid. best loss: 1.043868
# Epoch 4, train accuracy: 85.0000%, valid. accuracy: 72.8205%, valid. best loss: 0.992879
# Epoch 5, train accuracy: 85.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.838822
# Epoch 6, train accuracy: 85.0000%, valid. accuracy: 76.4103%, valid. best loss: 0.801348
# Epoch 7, train accuracy: 90.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.801348
# Epoch 8, train accuracy: 85.0000%, valid. accuracy: 76.4103%, valid. best loss: 0.785244
# Epoch 9, train accuracy: 85.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.723190
# Epoch 10, train accuracy: 95.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.723190
# Epoch 11, train accuracy: 75.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.723190
# Epoch 12, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.723190
# Epoch 13, train accuracy: 95.0000%, valid. accuracy: 76.9231%, valid. best loss: 0.723190
# Epoch 14, train accuracy: 90.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.723190
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.723190
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.723190
# Epoch 17, train accuracy: 90.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.723190
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.723190
# Epoch 19, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.723190
# Epoch 20, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.723190
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.723190
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.723190
# Epoch 23, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.723190
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.723190
# Epoch 25, train accuracy: 95.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.723190
# Early stopping!
# Final accuracy on test set: 0.817143
# Training and testing fold 3
# ranges:
# 350 700
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 35.0000%, valid. accuracy: 34.3590%, valid. best loss: 2.621524
# Epoch 1, train accuracy: 70.0000%, valid. accuracy: 53.3333%, valid. best loss: 1.315428
# Epoch 2, train accuracy: 80.0000%, valid. accuracy: 60.0000%, valid. best loss: 1.282021
# Epoch 3, train accuracy: 90.0000%, valid. accuracy: 69.7436%, valid. best loss: 0.941253
# Epoch 4, train accuracy: 80.0000%, valid. accuracy: 70.7692%, valid. best loss: 0.941253
# Epoch 5, train accuracy: 80.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.848344
# Epoch 6, train accuracy: 90.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.706635
# Epoch 7, train accuracy: 80.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.706635
# Epoch 8, train accuracy: 90.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.706635
# Epoch 9, train accuracy: 85.0000%, valid. accuracy: 71.2821%, valid. best loss: 0.706635
# Epoch 10, train accuracy: 90.0000%, valid. accuracy: 69.7436%, valid. best loss: 0.706635
# Epoch 11, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.706635
# Epoch 12, train accuracy: 90.0000%, valid. accuracy: 80.0000%, valid. best loss: 0.706635
# Epoch 13, train accuracy: 95.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.593970
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.593970
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.593970
# Epoch 16, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.593970
# Epoch 17, train accuracy: 95.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.593970
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 80.0000%, valid. best loss: 0.593970
# Epoch 19, train accuracy: 95.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.593970
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.593970
# Epoch 21, train accuracy: 90.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.593970
# Epoch 22, train accuracy: 95.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.593970
# Epoch 23, train accuracy: 95.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.593970
# Epoch 24, train accuracy: 95.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.593970
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.593970
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.593970
# Epoch 27, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.593970
# Epoch 28, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.593970
# Epoch 29, train accuracy: 95.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.593970
# Early stopping!
# Final accuracy on test set: 0.834286
# Training and testing fold 4
# ranges:
# 0 350
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 40.0000%, valid. accuracy: 34.8718%, valid. best loss: 2.563495
# Epoch 1, train accuracy: 55.0000%, valid. accuracy: 52.8205%, valid. best loss: 1.496005
# Epoch 2, train accuracy: 60.0000%, valid. accuracy: 57.4359%, valid. best loss: 1.286480
# Epoch 3, train accuracy: 75.0000%, valid. accuracy: 68.2051%, valid. best loss: 1.106527
# Epoch 4, train accuracy: 90.0000%, valid. accuracy: 67.1795%, valid. best loss: 0.874892
# Epoch 5, train accuracy: 95.0000%, valid. accuracy: 69.2308%, valid. best loss: 0.874892
# Epoch 6, train accuracy: 90.0000%, valid. accuracy: 70.7692%, valid. best loss: 0.874892
# Epoch 7, train accuracy: 95.0000%, valid. accuracy: 74.3590%, valid. best loss: 0.797865
# Epoch 8, train accuracy: 90.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.797865
# Epoch 9, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.730574
# Epoch 10, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.730574
# Epoch 11, train accuracy: 95.0000%, valid. accuracy: 73.8462%, valid. best loss: 0.730574
# Epoch 12, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.730574
# Epoch 13, train accuracy: 95.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.730574
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.730574
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 80.0000%, valid. best loss: 0.730574
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.730574
# Epoch 17, train accuracy: 90.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.730574
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.730574
# Epoch 19, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.637198
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.637198
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.637198
# Epoch 22, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.637198
# Epoch 23, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.637198
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 80.0000%, valid. best loss: 0.637198
# Epoch 25, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.637198
# Epoch 26, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.637198
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.637198
# Epoch 28, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.637198
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.637198
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.637198
# Epoch 31, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.637198
# Epoch 32, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.637198
# Epoch 33, train accuracy: 95.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.637198
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.637198
# Early stopping!
# Final accuracy on test set: 0.831429
# ******************************************
# {'n_hidden_layers': 5, 'n_neurons': 700, 'optimizer_class': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.01, 'batch_size': 50, 'activation': <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF1E0BA048>, 'dropout_rate': 0.2, 'conv1': {'conv1_fmaps': 16, 'conv1_ksize': 5, 'conv1_stride': 1, 'conv1_dropout': None, 'conv1_activation': <function relu at 0x000001AF17B97F28>}, 'conv2': {'conv2_fmaps': 32, 'conv2_ksize': 5, 'conv2_stride': 1, 'conv2_dropout': 0.2, 'conv2_activation': <function relu at 0x000001AF17B97F28>}, 'architecture': 2, 'accuracy_rate': 0.83028566837310791}
# ******************************************
# Trining CNN with parameters: n_hidden_layers: 5, n_neurons: 700, optimizer_class: <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, learning_rate: 0, batch_size: 50, activation: <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF1E0BA048>, dropout_rate: 0, architecture: 2, conv1: {'conv1_fmaps': 16, 'conv1_ksize': 5, 'conv1_stride': 1, 'conv1_dropout': None, 'conv1_activation': <function relu at 0x000001AF17B97F28>}, conv2: {'conv2_fmaps': 32, 'conv2_ksize': 5, 'conv2_stride': 1, 'conv2_dropout': 0.2, 'conv2_activation': <function relu at 0x000001AF17B97F28>} .
# Training and testing fold 0
# ranges:
# 1400 1750
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 55.0000%, valid. accuracy: 40.0000%, valid. best loss: 2.701408
# Epoch 1, train accuracy: 40.0000%, valid. accuracy: 53.8462%, valid. best loss: 1.895057
# Epoch 2, train accuracy: 75.0000%, valid. accuracy: 59.4872%, valid. best loss: 1.088285
# Epoch 3, train accuracy: 75.0000%, valid. accuracy: 64.6154%, valid. best loss: 1.010411
# Epoch 4, train accuracy: 95.0000%, valid. accuracy: 72.8205%, valid. best loss: 0.976615
# Epoch 5, train accuracy: 85.0000%, valid. accuracy: 70.2564%, valid. best loss: 0.976615
# Epoch 6, train accuracy: 95.0000%, valid. accuracy: 73.8462%, valid. best loss: 0.906450
# Epoch 7, train accuracy: 95.0000%, valid. accuracy: 74.3590%, valid. best loss: 0.827781
# Epoch 8, train accuracy: 90.0000%, valid. accuracy: 73.8462%, valid. best loss: 0.791906
# Epoch 9, train accuracy: 95.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.791906
# Epoch 10, train accuracy: 95.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.767100
# Epoch 11, train accuracy: 90.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.767100
# Epoch 12, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.642870
# Epoch 13, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.642870
# Epoch 14, train accuracy: 95.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.642870
# Epoch 15, train accuracy: 90.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.642870
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.642870
# Epoch 17, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.642870
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.641627
# Epoch 19, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.641627
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.641627
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.641627
# Epoch 22, train accuracy: 90.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.641627
# Epoch 23, train accuracy: 85.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.641627
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.641627
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.641627
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.641627
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.641627
# Epoch 28, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.641627
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.641627
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.641627
# Epoch 31, train accuracy: 90.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.641627
# Epoch 32, train accuracy: 95.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.641627
# Epoch 33, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.641627
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.641627
# Early stopping!
# Final accuracy on test set: 0.794286
# Training and testing fold 1
# ranges:
# 1050 1400
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 50.0000%, valid. accuracy: 28.7179%, valid. best loss: 2.510684
# Epoch 1, train accuracy: 60.0000%, valid. accuracy: 44.6154%, valid. best loss: 1.792037
# Epoch 2, train accuracy: 80.0000%, valid. accuracy: 47.1795%, valid. best loss: 1.288301
# Epoch 3, train accuracy: 75.0000%, valid. accuracy: 64.1026%, valid. best loss: 1.231803
# Epoch 4, train accuracy: 70.0000%, valid. accuracy: 66.6667%, valid. best loss: 1.155851
# Epoch 5, train accuracy: 80.0000%, valid. accuracy: 68.7180%, valid. best loss: 0.942462
# Epoch 6, train accuracy: 80.0000%, valid. accuracy: 66.1538%, valid. best loss: 0.942462
# Epoch 7, train accuracy: 100.0000%, valid. accuracy: 72.8205%, valid. best loss: 0.742366
# Epoch 8, train accuracy: 100.0000%, valid. accuracy: 73.3333%, valid. best loss: 0.742366
# Epoch 9, train accuracy: 90.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.742366
# Epoch 10, train accuracy: 80.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.742366
# Epoch 11, train accuracy: 90.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.742366
# Epoch 12, train accuracy: 95.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.742366
# Epoch 13, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.729465
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.729465
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.729465
# Epoch 16, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.729465
# Epoch 17, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.729465
# Epoch 18, train accuracy: 95.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.729465
# Epoch 19, train accuracy: 100.0000%, valid. accuracy: 76.9231%, valid. best loss: 0.729465
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.715742
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.715742
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.715742
# Epoch 23, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.715742
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.634602
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.634602
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.634602
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.634602
# Epoch 28, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.634602
# Epoch 29, train accuracy: 95.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.634602
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.634602
# Epoch 31, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.634602
# Epoch 32, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.634602
# Epoch 33, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.634602
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.634602
# Epoch 35, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.634602
# Epoch 36, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.634602
# Epoch 37, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.634602
# Epoch 38, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.634602
# Epoch 39, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.634602
# Epoch 40, train accuracy: 95.0000%, valid. accuracy: 87.1795%, valid. best loss: 0.634602
# Early stopping!
# Final accuracy on test set: 0.84
# Training and testing fold 2
# ranges:
# 700 1050
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 35.0000%, valid. accuracy: 26.6667%, valid. best loss: 3.058372
# Epoch 1, train accuracy: 60.0000%, valid. accuracy: 44.1026%, valid. best loss: 1.800675
# Epoch 2, train accuracy: 70.0000%, valid. accuracy: 61.5385%, valid. best loss: 1.537298
# Epoch 3, train accuracy: 80.0000%, valid. accuracy: 70.7692%, valid. best loss: 1.049910
# Epoch 4, train accuracy: 75.0000%, valid. accuracy: 67.6923%, valid. best loss: 1.049910
# Epoch 5, train accuracy: 75.0000%, valid. accuracy: 67.1795%, valid. best loss: 1.049910
# Epoch 6, train accuracy: 95.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.757355
# Epoch 7, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.757355
# Epoch 8, train accuracy: 100.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.753081
# Epoch 9, train accuracy: 95.0000%, valid. accuracy: 76.9231%, valid. best loss: 0.666760
# Epoch 10, train accuracy: 80.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.666760
# Epoch 11, train accuracy: 85.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.666760
# Epoch 12, train accuracy: 100.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.666760
# Epoch 13, train accuracy: 85.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.666760
# Epoch 14, train accuracy: 95.0000%, valid. accuracy: 77.9487%, valid. best loss: 0.666760
# Epoch 15, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.666760
# Epoch 16, train accuracy: 90.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.587141
# Epoch 17, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.587141
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.587141
# Epoch 19, train accuracy: 85.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.587141
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.587141
# Epoch 21, train accuracy: 95.0000%, valid. accuracy: 78.4615%, valid. best loss: 0.576185
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.576185
# Epoch 23, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.576185
# Epoch 24, train accuracy: 95.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.576185
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.576185
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 87.6923%, valid. best loss: 0.576185
# Epoch 27, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.576185
# Epoch 28, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.576185
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.576185
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.576185
# Epoch 31, train accuracy: 90.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.576185
# Epoch 32, train accuracy: 100.0000%, valid. accuracy: 87.1795%, valid. best loss: 0.532363
# Epoch 33, train accuracy: 95.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.532363
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.532363
# Epoch 35, train accuracy: 100.0000%, valid. accuracy: 88.2051%, valid. best loss: 0.532363
# Epoch 36, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.532363
# Epoch 37, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.532363
# Epoch 38, train accuracy: 100.0000%, valid. accuracy: 88.7179%, valid. best loss: 0.532363
# Epoch 39, train accuracy: 90.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.532363
# Epoch 40, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.532363
# Epoch 41, train accuracy: 100.0000%, valid. accuracy: 87.6923%, valid. best loss: 0.532363
# Epoch 42, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.532363
# Epoch 43, train accuracy: 95.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.532363
# Epoch 44, train accuracy: 100.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.532363
# Epoch 45, train accuracy: 95.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.532363
# Epoch 46, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.532363
# Epoch 47, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.532363
# Epoch 48, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.532363
# Early stopping!
# Final accuracy on test set: 0.88
# Training and testing fold 3
# ranges:
# 350 700
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 55.0000%, valid. accuracy: 34.3590%, valid. best loss: 2.693235
# Epoch 1, train accuracy: 60.0000%, valid. accuracy: 50.7692%, valid. best loss: 1.686746
# Epoch 2, train accuracy: 85.0000%, valid. accuracy: 51.2821%, valid. best loss: 1.107721
# Epoch 3, train accuracy: 80.0000%, valid. accuracy: 68.7180%, valid. best loss: 1.053527
# Epoch 4, train accuracy: 75.0000%, valid. accuracy: 73.8462%, valid. best loss: 0.998083
# Epoch 5, train accuracy: 85.0000%, valid. accuracy: 72.8205%, valid. best loss: 0.800515
# Epoch 6, train accuracy: 75.0000%, valid. accuracy: 77.4359%, valid. best loss: 0.800515
# Epoch 7, train accuracy: 85.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.753783
# Epoch 8, train accuracy: 85.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.753783
# Epoch 9, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.753783
# Epoch 10, train accuracy: 95.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.737661
# Epoch 11, train accuracy: 100.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.737661
# Epoch 12, train accuracy: 75.0000%, valid. accuracy: 75.8974%, valid. best loss: 0.737661
# Epoch 13, train accuracy: 90.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.737661
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.726912
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.553560
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.553560
# Epoch 17, train accuracy: 95.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.553560
# Epoch 18, train accuracy: 90.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.553560
# Epoch 19, train accuracy: 95.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.553560
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.553560
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.553560
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.553560
# Epoch 23, train accuracy: 90.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.553560
# Epoch 24, train accuracy: 95.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.553560
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.553560
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 80.0000%, valid. best loss: 0.553560
# Epoch 27, train accuracy: 100.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.553560
# Epoch 28, train accuracy: 90.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.553560
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.553560
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.553560
# Epoch 31, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.553560
# Early stopping!
# Final accuracy on test set: 0.851429
# Training and testing fold 4
# ranges:
# 0 350
# shapes:
# (1404, 12, 80, 1) (350, 12, 80, 1)
# (1404,) (350,)
# Epoch 0, train accuracy: 55.0000%, valid. accuracy: 35.8974%, valid. best loss: 2.751712
# Epoch 1, train accuracy: 60.0000%, valid. accuracy: 41.0256%, valid. best loss: 1.698937
# Epoch 2, train accuracy: 40.0000%, valid. accuracy: 62.5641%, valid. best loss: 1.309890
# Epoch 3, train accuracy: 55.0000%, valid. accuracy: 62.0513%, valid. best loss: 1.143146
# Epoch 4, train accuracy: 80.0000%, valid. accuracy: 74.8718%, valid. best loss: 0.864084
# Epoch 5, train accuracy: 75.0000%, valid. accuracy: 71.7949%, valid. best loss: 0.808687
# Epoch 6, train accuracy: 90.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.755095
# Epoch 7, train accuracy: 80.0000%, valid. accuracy: 75.3846%, valid. best loss: 0.755095
# Epoch 8, train accuracy: 95.0000%, valid. accuracy: 78.9744%, valid. best loss: 0.755095
# Epoch 9, train accuracy: 95.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.702013
# Epoch 10, train accuracy: 90.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.702013
# Epoch 11, train accuracy: 95.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.627713
# Epoch 12, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.579052
# Epoch 13, train accuracy: 90.0000%, valid. accuracy: 83.0769%, valid. best loss: 0.579052
# Epoch 14, train accuracy: 100.0000%, valid. accuracy: 76.9231%, valid. best loss: 0.579052
# Epoch 15, train accuracy: 100.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.579052
# Epoch 16, train accuracy: 95.0000%, valid. accuracy: 79.4872%, valid. best loss: 0.579052
# Epoch 17, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.579052
# Epoch 18, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.579052
# Epoch 19, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.579052
# Epoch 20, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.579052
# Epoch 21, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.579052
# Epoch 22, train accuracy: 100.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.579052
# Epoch 23, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.579052
# Epoch 24, train accuracy: 100.0000%, valid. accuracy: 83.5897%, valid. best loss: 0.510110
# Epoch 25, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.510110
# Epoch 26, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.510110
# Epoch 27, train accuracy: 90.0000%, valid. accuracy: 81.5385%, valid. best loss: 0.510110
# Epoch 28, train accuracy: 100.0000%, valid. accuracy: 88.2051%, valid. best loss: 0.510110
# Epoch 29, train accuracy: 100.0000%, valid. accuracy: 87.6923%, valid. best loss: 0.436052
# Epoch 30, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.436052
# Epoch 31, train accuracy: 100.0000%, valid. accuracy: 87.1795%, valid. best loss: 0.436052
# Epoch 32, train accuracy: 100.0000%, valid. accuracy: 86.6667%, valid. best loss: 0.436052
# Epoch 33, train accuracy: 100.0000%, valid. accuracy: 84.1026%, valid. best loss: 0.436052
# Epoch 34, train accuracy: 100.0000%, valid. accuracy: 85.6410%, valid. best loss: 0.436052
# Epoch 35, train accuracy: 100.0000%, valid. accuracy: 87.1795%, valid. best loss: 0.436052
# Epoch 36, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.436052
# Epoch 37, train accuracy: 100.0000%, valid. accuracy: 86.1538%, valid. best loss: 0.436052
# Epoch 38, train accuracy: 100.0000%, valid. accuracy: 84.6154%, valid. best loss: 0.436052
# Epoch 39, train accuracy: 100.0000%, valid. accuracy: 85.1282%, valid. best loss: 0.436052
# Epoch 40, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.436052
# Epoch 41, train accuracy: 95.0000%, valid. accuracy: 81.0256%, valid. best loss: 0.436052
# Epoch 42, train accuracy: 100.0000%, valid. accuracy: 80.5128%, valid. best loss: 0.436052
# Epoch 43, train accuracy: 95.0000%, valid. accuracy: 82.5641%, valid. best loss: 0.436052
# Epoch 44, train accuracy: 95.0000%, valid. accuracy: 82.0513%, valid. best loss: 0.436052
# Early stopping!
# Final accuracy on test set: 0.828571
# ******************************************
# {'n_hidden_layers': 5, 'n_neurons': 700, 'optimizer_class': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.05, 'batch_size': 50, 'activation': <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF1E0BA048>, 'dropout_rate': 0.2, 'conv1': {'conv1_fmaps': 16, 'conv1_ksize': 5, 'conv1_stride': 1, 'conv1_dropout': None, 'conv1_activation': <function relu at 0x000001AF17B97F28>}, 'conv2': {'conv2_fmaps': 32, 'conv2_ksize': 5, 'conv2_stride': 1, 'conv2_dropout': 0.2, 'conv2_activation': <function relu at 0x000001AF17B97F28>}, 'architecture': 2, 'accuracy_rate': 0.83885713815689089}
# ******************************************
# Best parameters:
# {'n_hidden_layers': 5, 'n_neurons': 700, 'optimizer_class': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.05, 'batch_size': 50, 'activation': <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF1E0BA048>, 'dropout_rate': 0.2, 'conv1': {'conv1_fmaps': 16, 'conv1_ksize': 5, 'conv1_stride': 1, 'conv1_dropout': None, 'conv1_activation': <function relu at 0x000001AF17B97F28>}, 'conv2': {'conv2_fmaps': 32, 'conv2_ksize': 5, 'conv2_stride': 1, 'conv2_dropout': 0.2, 'conv2_activation': <function relu at 0x000001AF17B97F28>}, 'architecture': 2, 'accuracy_rate': 0.83885713815689089}

# %%
# global cnn
cnn = CNNClassifier(batch_size=50, learning_rate=0.01, n_hidden_layers=5, n_neurons=700, 
                    optimizer_class=tf.train.AdagradOptimizer, activation=leaky_relu(alpha=0.01), 
                    conv1={'conv1_fmaps':16, 'conv1_ksize':5, 'conv1_stride':1, 'conv1_dropout':0.2},
                   conv2={'conv2_fmaps':32, 'conv2_ksize':5, 'conv2_stride':1, 'conv2_dropout':0.4})
range1 = 0
range2 = 350
X_train2 = X_train[:range1]
X_train2 = np.vstack([X_train2, X_train[range2:]])
print(X_train2.shape)
y_train2 = y_train[:range1]
y_train2 = np.append(y_train2, y_train[range2:])

X_test2 = X_test[range1:range2]
y_test2 = y_test[range1:range2]

#cnn.fit(X_train=X_train[350:], y_train=y_train[350:], X_valid=X_valid, y_valid=y_valid)
cnn.fit(X_train=X_train2, y_train=y_train2, X_valid=None, y_valid=None)

score = cnn.accuracy_score(X_test2, y_test2)
score

# %%
import tensorflow as tf

X_train_reshaped = np.reshape(X_train,(len(X_train), -1))
X_valid_reshaped = np.reshape(X_valid,(len(X_valid), -1))
X_test_reshaped = np.reshape(X_test,(len(X_test), -1))

def leaky_relu(alpha=0.01):
		def parametrized_leaky_relu(z, name=None):
			return tf.maximum(alpha * z, z, name=name)
		return parametrized_leaky_relu

params = {'n_hidden_layers': [5],
	'n_neurons' : [1000],
	'optimizer_class' : [tf.train.AdagradOptimizer],
	'learning_rate' : [0.01],
	'batch_size' : [50],
	'activation' : [leaky_relu()],
	'dropout_rate' : [0.2]
}

grid_search = GridSearchDNN(params, k_fold=5)
grid_search.fit(X_train_reshaped, y_train, X_valid_reshaped, y_valid)
# Out:
# Trining DNN with parameters: n_hidden_layers: 5, n_neurons: 1000, optimizer_class: <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, learning_rate: 0, batch_size: 50, activation: <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001AF19702AE8>, dropout_rate: 0,
# Training and testing fold 0
# ranges:
# 1400 1750
# shapes:
# (1404, 960) (350, 960)
# (1404,) (350,)
# 0	Validation loss: 1.538791	Best loss: 1.538791	Accuracy: 60.00%
# 1	Validation loss: 1.115685	Best loss: 1.115685	Accuracy: 66.67%
# 2	Validation loss: 0.895158	Best loss: 0.895158	Accuracy: 72.82%
# 3	Validation loss: 0.777443	Best loss: 0.777443	Accuracy: 77.95%
# 4	Validation loss: 0.979103	Best loss: 0.777443	Accuracy: 69.74%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e853fba0b3fc> in <module>()
#      20
#      21 grid_search = GridSearchDNN(params, k_fold=5)
# ---> 22 grid_search.fit(X_train_reshaped, y_train, X_valid_reshaped, y_valid)
#
# ~\Dropbox\Github_Projects\TCC\TCC_app\server_Universal_Tuner\api\AI\dataset\backup\NN_model.py in fit(self, X, y, X_valid, y_valid)
#     714 											learning_rate=learning_rate, activation=activation)
#     715
# --> 716                                                                                 dnn.fit(X=X_train, y=y_train, X_valid=X_valid, y_valid=y_valid)
#     717                                                                                 accuracy_rate += dnn.accuracy_score(X_test, y_test)
#     718                                                                                 del dnn
#
# ~\Dropbox\Github_Projects\TCC\TCC_app\server_Universal_Tuner\api\AI\dataset\backup\NN_model.py in fit(self, X, y, n_epochs, X_valid, y_valid)
#     142                                         if self._training is not None:
#     143                                                 feed_dict[self._training] = True
# --> 144                                         sess.run(self._training_op, feed_dict=feed_dict)
#     145                                         if extra_update_ops:
#     146                                                 sess.run(extra_update_ops, feed_dict=feed_dict)
#
# ~\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Out:
# Trining DNN with parameters: n_hidden_layers: 5, n_neurons: 1000, optimizer_class: <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, learning_rate: 0, batch_size: 50, activation: <function leaky_relu.<locals>.parametrized_leaky_relu at 0x000001F1E24536A8>, dropout_rate: 0,
# Training and testing fold 0
# ranges:
# 1540 1925
# shapes:
# (1544, 960) (385, 960)
# (1544,) (385,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e853fba0b3fc> in <module>()
#      20
#      21 grid_search = GridSearchDNN(params, k_fold=5)
# ---> 22 grid_search.fit(X_train_reshaped, y_train, X_valid_reshaped, y_valid)
#
# ~\Dropbox\Github_Projects\TCC\TCC_app\server_Universal_Tuner\api\AI\dataset\backup\NN_model.py in fit(self, X, y, X_valid, y_valid)
#     588 											learning_rate=learning_rate, activation=activation)
#     589
# --> 590                                                                                 dnn.fit(X_train=X_train, y_train=y_train, X_valid=X_valid, y_valid=y_valid)
#     591                                                                                 accuracy_rate += dnn.accuracy_score(X_test, y_test)
#     592                                                                                 del dnn
#
# TypeError: fit() got an unexpected keyword argument 'X_train'
